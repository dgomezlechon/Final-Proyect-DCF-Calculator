# %% [markdown]
# # Financial Statements Extraction

# %% [markdown]
# We are going to extract the income statement, balance sheet and cash flow statement from "morningstar.com". We will do this by using Selenium and Beautiful soup

# %%
#%pip install selenium

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time 


from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
#%pip install openpyxl
from apifunctions import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [125], in <cell line: 2>()
#       1 #%pip install openpyxl
# ----> 2 from apifunctions import *
#
# ModuleNotFoundError: No module named 'apifunctions'

# %%
#%pip install xlrd

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')


import warnings
warnings.filterwarnings('ignore')

PATH=ChromeDriverManager().install()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 101.0.4951
# Get LATEST chromedriver version for 101.0.4951 google-chrome
# There is no [mac64] chromedriver for browser 101.0.4951 in cache
# Trying to download new driver from https://chromedriver.storage.googleapis.com/101.0.4951.41/chromedriver_mac64.zip
# Driver has been saved in cache [/Users/danigomezlechonbarrachina/.wdm/drivers/chromedriver/mac64/101.0.4951.41]

# %% [markdown]
# Solicitamos que se introduzca la compañía a analizar

# %%
print("Enter company ticker:")
x=input()
print('The chosen company ticker is:' + x) #en minúscula
# Out:
# Enter company ticker:
# AMCX
# The chosen company ticker is:AMCX

# %%
def is_scrapping(ticker):

    '''esta funcion nos descarga y convierte a dataframe el income statement de una empresa'''
    
    url1="https://www.morningstar.com/stocks/xnas/"
    url2=ticker+"/financials"
    url=url1+url2

    driver=webdriver.Chrome(PATH, options = opciones)
    driver.get(url)

    #pinchamos en "see details"
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#__layout > div > div.mdc-page-shell.mds-page-shell.default-layout > div.mdc-page-shell__content.mds-page-shell__content > main > div.stock__content > div > div > div.mdc-column.mds-layout-grid__col.stock__content-sal.mds-layout-grid__col--12.mds-layout-grid__col--auto-at-1092 > div > div > sal-components > section > div > div > div > sal-components-new-financials > div > div:nth-child(2) > div > div > div.sal-component-body > div > sal-components-financials-summary > div > div:nth-child(2) > div > div.sal-component-body > div > div > div.sal-summary-section__header.sal-icon-link > a"))).click()

    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#__layout > div > div.mdc-page-shell.mds-page-shell.default-layout > div.mdc-page-shell__content.mds-page-shell__content > main > div.stock__content > div > div > div.mdc-column.mds-layout-grid__col.stock__content-sal.mds-layout-grid__col--12.mds-layout-grid__col--auto-at-1092 > div > div > sal-components > section > div > div > div > sal-components-new-financials > div > div:nth-child(2) > div > div > sal-components-financials-details > div > div > div > div.sal-component-header > div.sal-financials-details__exportSection > button"))).click()

    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#__layout > div > div.mdc-page-shell.mds-page-shell.default-layout > div.mdc-page-shell__content.mds-page-shell__content > main > div.stock__content > div > div > div.mdc-column.mds-layout-grid__col.stock__content-sal.mds-layout-grid__col--12.mds-layout-grid__col--auto-at-1092 > div > div > sal-components > section > div > div > div > sal-components-new-financials > div > div:nth-child(2) > div > div > sal-components-financials-details > div > div > div > div.sal-component-header > div.sal-financials-details__exportSection > button"))).click()

    ruta="/Users/danigomezlechonbarrachina/Downloads/Income Statement_Annual_As Originally Reported.xls"

    inc_statement=pd.read_excel(ruta)
    
    inc_statement=inc_statement[["AMCX_income-statement_Annual_As_Originally_Reported","2019","2020","2021"]]
    
    inc_statement.set_index("AMCX_income-statement_Annual_As_Originally_Reported",inplace=True)

# %%
def bs_scrapping(ticker):

    '''esta funcion nos descarga y convierte a dataframe el income statement de una empresa'''
    
    url1="https://www.morningstar.com/stocks/xnas/"
    url2=ticker+"/financials"
    url=url1+url2

    driver=webdriver.Chrome(PATH, options = opciones)
    driver.get(url)

    #pinchamos en "see details"
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#__layout > div > div.mdc-page-shell.mds-page-shell.default-layout > div.mdc-page-shell__content.mds-page-shell__content > main > div.stock__content > div > div > div.mdc-column.mds-layout-grid__col.stock__content-sal.mds-layout-grid__col--12.mds-layout-grid__col--auto-at-1092 > div > div > sal-components > section > div > div > div > sal-components-new-financials > div > div:nth-child(2) > div > div > div.sal-component-body > div > sal-components-financials-summary > div > div:nth-child(2) > div > div.sal-component-body > div > div > div.sal-summary-section__header.sal-icon-link > a"))).click()

    #pinchamos en "see details"
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="balanceSheet"]'))).click()
    
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#__layout > div > div.mdc-page-shell.mds-page-shell.default-layout > div.mdc-page-shell__content.mds-page-shell__content > main > div.stock__content > div > div > div.mdc-column.mds-layout-grid__col.stock__content-sal.mds-layout-grid__col--12.mds-layout-grid__col--auto-at-1092 > div > div > sal-components > section > div > div > div > sal-components-new-financials > div > div:nth-child(2) > div > div > sal-components-financials-details > div > div > div > div.sal-component-header > div.sal-financials-details__exportSection > button"))).click()

    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#__layout > div > div.mdc-page-shell.mds-page-shell.default-layout > div.mdc-page-shell__content.mds-page-shell__content > main > div.stock__content > div > div > div.mdc-column.mds-layout-grid__col.stock__content-sal.mds-layout-grid__col--12.mds-layout-grid__col--auto-at-1092 > div > div > sal-components > section > div > div > div > sal-components-new-financials > div > div:nth-child(2) > div > div > sal-components-financials-details > div > div > div > div.sal-component-header > div.sal-financials-details__exportSection > button"))).click()

    ruta="/Users/danigomezlechonbarrachina/Downloads/AMCX_balance-sheet_Annual_As_Originally_Reported.xls"

    balance_sheet=pd.read_excel(ruta)
    
    balance_sheet=balance_sheet[["AMCX_balance-sheet_Annual_As_Originally_Reported","2019","2020","2021"]]
    
    balance_sheet.set_index("AMCX_balance-sheet_Annual_As_Originally_Reported",inplace=True)

# %%
bs_scrapping(x)  #sacamos el IS como un dataframe
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Input In [154], in <cell line: 1>()
# ----> 1 bs_scrapping(x)
#
# Input In [153], in bs_scrapping(ticker)
#      13 WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#__layout > div > div.mdc-page-shell.mds-page-shell.default-layout > div.mdc-page-shell__content.mds-page-shell__content > main > div.stock__content > div > div > div.mdc-column.mds-layout-grid__col.stock__content-sal.mds-layout-grid__col--12.mds-layout-grid__col--auto-at-1092 > div > div > sal-components > section > div > div > div > sal-components-new-financials > div > div:nth-child(2) > div > div > div.sal-component-body > div > sal-components-financials-summary > div > div:nth-child(2) > div > div.sal-component-body > div > div > div.sal-summary-section__header.sal-icon-link > a"))).click()
#      15 #pinchamos en "see details"
# ---> 16 WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="balanceSheet"]'))).click()
#      18 WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#__layout > div > div.mdc-page-shell.mds-page-shell.default-layout > div.mdc-page-shell__content.mds-page-shell__content > main > div.stock__content > div > div > div.mdc-column.mds-layout-grid__col.stock__content-sal.mds-layout-grid__col--12.mds-layout-grid__col--auto-at-1092 > div > div > sal-components > section > div > div > div > sal-components-new-financials > div > div:nth-child(2) > div > div > sal-components-financials-details > div > div > div > div.sal-component-header > div.sal-financials-details__exportSection > button"))).click()
#      20 WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "#__layout > div > div.mdc-page-shell.mds-page-shell.default-layout > div.mdc-page-shell__content.mds-page-shell__content > main > div.stock__content > div > div > div.mdc-column.mds-layout-grid__col.stock__content-sal.mds-layout-grid__col--12.mds-layout-grid__col--auto-at-1092 > div > div > sal-components > section > div > div > div > sal-components-new-financials > div > div:nth-child(2) > div > div > sal-components-financials-details > div > div > div > div.sal-component-header > div.sal-financials-details__exportSection > button"))).click()
#
# File ~/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages/selenium/webdriver/support/wait.py:78, in WebDriverWait.until(self, method, message)
#      76 while True:
#      77     try:
# ---> 78         value = method(self._driver)
#      79         if value:
#      80             return value
#
# File ~/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages/selenium/webdriver/support/expected_conditions.py:327, in element_to_be_clickable.<locals>._predicate(driver)
#     325 if not isinstance(target, WebElement):  # if given locator instead of WebElement
#     326     target = driver.find_element(*target)  # grab element at locator
# --> 327 target = visibility_of(target)(driver)
#     328 if target and target.is_enabled():
#     329     return target
#
# File ~/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages/selenium/webdriver/support/expected_conditions.py:143, in visibility_of.<locals>._predicate(_)
#     142 def _predicate(_):
# --> 143     return _element_if_visible(element)
#
# File ~/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages/selenium/webdriver/support/expected_conditions.py:149, in _element_if_visible(element, visibility)
#     148 def _element_if_visible(element, visibility=True):
# --> 149     return element if element.is_displayed() == visibility else False
#
# File ~/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:564, in WebElement.is_displayed(self)
#     562 """Whether the element is visible to a user."""
#     563 # Only go into this conditional for browsers that don't use the atom themselves
# --> 564 return self.parent.execute_script(
#     565     "return (%s).apply(null, arguments);" % isDisplayed_js,
#     566     self)
#
# File ~/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:879, in WebDriver.execute_script(self, script, *args)
#     876 converted_args = list(args)
#     877 command = Command.W3C_EXECUTE_SCRIPT
# --> 879 return self.execute(command, {
#     880     'script': script,
#     881     'args': converted_args})['value']
#
# File ~/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:425, in WebDriver.execute(self, driver_command, params)
#     423 response = self.command_executor.execute(driver_command, params)
#     424 if response:
# --> 425     self.error_handler.check_response(response)
#     426     response['value'] = self._unwrap_value(
#     427         response.get('value', None))
#     428     return response
#
# File ~/opt/anaconda3/envs/Ironhack/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=101.0.4951.54)
# Stacktrace:
# 0   chromedriver                        0x00000001076502c9 chromedriver + 5120713
# 1   chromedriver                        0x00000001075dee33 chromedriver + 4656691
# 2   chromedriver                        0x00000001071ce158 chromedriver + 393560
# 3   chromedriver                        0x00000001071d1087 chromedriver + 405639
# 4   chromedriver                        0x00000001071d0f26 chromedriver + 405286
# 5   chromedriver                        0x00000001071d1aed chromedriver + 408301
# 6   chromedriver                        0x0000000107233b63 chromedriver + 809827
# 7   chromedriver                        0x0000000107220482 chromedriver + 730242
# 8   chromedriver                        0x0000000107232f41 chromedriver + 806721
# 9   chromedriver                        0x0000000107220373 chromedriver + 729971
# 10  chromedriver                        0x00000001071f6609 chromedriver + 558601
# 11  chromedriver                        0x00000001071f7635 chromedriver + 562741
# 12  chromedriver                        0x0000000107622b1d chromedriver + 4934429
# 13  chromedriver                        0x0000000107627295 chromedriver + 4952725
# 14  chromedriver                        0x000000010762c3cf chromedriver + 4973519
# 15  chromedriver                        0x0000000107627cba chromedriver + 4955322
# 16  chromedriver                        0x000000010760237c chromedriver + 4801404
# 17  chromedriver                        0x0000000107641c68 chromedriver + 5061736
# 18  chromedriver                        0x0000000107641def chromedriver + 5062127
# 19  chromedriver                        0x00000001076575e5 chromedriver + 5150181
# 20  libsystem_pthread.dylib             0x00007fff203f58fc _pthread_start + 224
# 21  libsystem_pthread.dylib             0x00007fff203f1443 thread_start + 15

# %%
inc_statement
# Out:
#                                                               2019  \
# AMCX_income-statement_Annual_As_Originally_Repo...
# Gross Profit                                         1,553,336,000
#     Total Revenue                                    3,060,321,000
#         Business Revenue                             3,060,321,000
#     Cost of Revenue                                 -1,506,985,000
#         Cost of Goods and Services                  -1,506,985,000
# Operating Income/Expenses                             -780,542,000
#     Selling, General and Administrative Expenses      -679,444,000
#     Depreciation, Amortization and Depletion          -101,098,000
#         Depreciation and Amortization                 -101,098,000
# Total Operating Profit/Loss                            772,794,000
# Non-Operating Income/Expenses, Total                  -286,608,000
#     Total Net Finance Income/Expense                  -133,091,000
#         Net Interest Income/Expense                   -133,091,000
#             Interest Expense Net of Capitalized...    -157,798,000
#             Interest Income                             24,707,000
#     Irregular Income/Expenses                         -147,517,000
#         Impairment/Write Off/Write Down of Othe...             NaN
#         Gain/Loss on Extinguishment of Debt                      0
#         Restructuring and Reorganization Income...     -40,914,000
#         Goodwill Impairment/Write Off                 -106,603,000
#         Litigation Income/Expense                              NaN
#     Other Income/Expense, Non-Operating                 -6,000,000
# Pretax Income                                          486,186,000
# Provision for Income Tax                               -78,470,000
# Net Income from Continuing Operations                  407,716,000
# Net Income after Extraordinary Items and Discon...     407,716,000
# Non-Controlling/Minority Interests                     -27,230,000
# Net Income after Non-Controlling/Minority Inter...     380,486,000
# Net Income Available to Common Stockholders            380,486,000
# Diluted Net Income Available to Common Stockhol...     380,486,000
# Income Statement Supplemental Section                          NaN
#     Reported Normalized and Operating Income/Ex...             NaN
#         Total Revenue as Reported, Supplemental      3,060,321,000
#         Operating Expense as Reported, Suppleme...  -2,435,044,000
#         Total Operating Profit/Loss as Reported...     625,277,000
#         Reported Normalized Income                     528,890,000
#         Reported Effective Tax Rate                           0.16
#         Reported Normalized Operating Profit           943,990,000
# Discontinued Operations                                        NaN
# Basic EPS                                                     6.77
#     Basic EPS from Continuing Operations                      6.77
#     Basic EPS from Discontinued Operations                     NaN
# Diluted EPS                                                   6.67
#     Diluted EPS from Continuing Operations                    6.67
#     Diluted EPS from Discontinued Operations                   NaN
# Basic Weighted Average Shares Outstanding               56,205,000
# Diluted Weighted Average Shares Outstanding             57,037,000
# Reported Normalized Diluted EPS                               9.27
# Basic EPS                                                     6.77
# Diluted EPS                                                   6.67
# Basic WASO                                              56,205,000
# Diluted WASO                                            57,037,000
# Fiscal year ends in Dec 31 | USD                               NaN
#
#                                                               2020  \
# AMCX_income-statement_Annual_As_Originally_Repo...
# Gross Profit                                         1,413,365,000
#     Total Revenue                                    2,814,956,000
#         Business Revenue                             2,814,956,000
#     Cost of Revenue                                 -1,401,591,000
#         Cost of Goods and Services                  -1,401,591,000
# Operating Income/Expenses                             -813,426,000
#     Selling, General and Administrative Expenses      -708,820,000
#     Depreciation, Amortization and Depletion          -104,606,000
#         Depreciation and Amortization                 -104,606,000
# Total Operating Profit/Loss                            599,939,000
# Non-Operating Income/Expenses, Total                  -197,560,000
#     Total Net Finance Income/Expense                  -108,578,000
#         Net Interest Income/Expense                   -108,578,000
#             Interest Expense Net of Capitalized...    -138,610,000
#             Interest Income                             30,032,000
#     Irregular Income/Expenses                         -160,203,000
#         Impairment/Write Off/Write Down of Othe...             NaN
#         Gain/Loss on Extinguishment of Debt             -2,908,000
#         Restructuring and Reorganization Income...     -35,068,000
#         Goodwill Impairment/Write Off                 -122,227,000
#         Litigation Income/Expense                              NaN
#     Other Income/Expense, Non-Operating                 71,221,000
# Pretax Income                                          402,379,000
# Provision for Income Tax                              -145,391,000
# Net Income from Continuing Operations                  256,988,000
# Net Income after Extraordinary Items and Discon...     256,988,000
# Non-Controlling/Minority Interests                     -17,009,000
# Net Income after Non-Controlling/Minority Inter...     239,979,000
# Net Income Available to Common Stockholders            239,979,000
# Diluted Net Income Available to Common Stockhol...     239,979,000
# Income Statement Supplemental Section                          NaN
#     Reported Normalized and Operating Income/Ex...             NaN
#         Total Revenue as Reported, Supplemental      2,814,956,000
#         Operating Expense as Reported, Suppleme...  -2,372,312,000
#         Total Operating Profit/Loss as Reported...     442,644,000
#         Reported Normalized Income                     401,368,000
#         Reported Effective Tax Rate                           0.36
#         Reported Normalized Operating Profit           766,611,000
# Discontinued Operations                                        NaN
# Basic EPS                                                     4.70
#     Basic EPS from Continuing Operations                      4.70
#     Basic EPS from Discontinued Operations                     NaN
# Diluted EPS                                                   4.64
#     Diluted EPS from Continuing Operations                    4.64
#     Diluted EPS from Discontinued Operations                   NaN
# Basic Weighted Average Shares Outstanding               51,016,000
# Diluted Weighted Average Shares Outstanding             51,733,000
# Reported Normalized Diluted EPS                               7.76
# Basic EPS                                                     4.70
# Diluted EPS                                                   4.64
# Basic WASO                                              51,016,000
# Diluted WASO                                            51,733,000
# Fiscal year ends in Dec 31 | USD                               NaN
#
#                                                               2021
# AMCX_income-statement_Annual_As_Originally_Repo...
# Gross Profit                                         1,645,525,000
#     Total Revenue                                    3,077,608,000
#         Business Revenue                             3,077,608,000
#     Cost of Revenue                                 -1,432,083,000
#         Cost of Goods and Services                  -1,432,083,000
# Operating Income/Expenses                             -985,615,000
#     Selling, General and Administrative Expenses      -891,734,000
#     Depreciation, Amortization and Depletion           -93,881,000
#         Depreciation and Amortization                  -93,881,000
# Total Operating Profit/Loss                            659,910,000
# Non-Operating Income/Expenses, Total                  -285,678,000
#     Total Net Finance Income/Expense                  -118,830,000
#         Net Interest Income/Expense                   -118,830,000
#             Interest Expense Net of Capitalized...    -129,073,000
#             Interest Income                             10,243,000
#     Irregular Income/Expenses                         -192,062,000
#         Impairment/Write Off/Write Down of Othe...    -159,610,000
#         Gain/Loss on Extinguishment of Debt            -22,074,000
#         Restructuring and Reorganization Income...     -10,378,000
#         Goodwill Impairment/Write Off                          NaN
#         Litigation Income/Expense                              NaN
#     Other Income/Expense, Non-Operating                 25,214,000
# Pretax Income                                          374,232,000
# Provision for Income Tax                               -94,393,000
# Net Income from Continuing Operations                  279,839,000
# Net Income after Extraordinary Items and Discon...     279,839,000
# Non-Controlling/Minority Interests                     -29,243,000
# Net Income after Non-Controlling/Minority Inter...     250,596,000
# Net Income Available to Common Stockholders            250,596,000
# Diluted Net Income Available to Common Stockhol...     250,596,000
# Income Statement Supplemental Section                          NaN
#     Reported Normalized and Operating Income/Ex...             NaN
#         Total Revenue as Reported, Supplemental      3,077,608,000
#         Operating Expense as Reported, Suppleme...  -2,587,686,000
#         Total Operating Profit/Loss as Reported...     489,922,000
#         Reported Normalized Income                     418,611,000
#         Reported Effective Tax Rate                           0.25
#         Reported Normalized Operating Profit           816,070,000
# Discontinued Operations                                        NaN
# Basic EPS                                                     5.92
#     Basic EPS from Continuing Operations                      5.92
#     Basic EPS from Discontinued Operations                     NaN
# Diluted EPS                                                   5.77
#     Diluted EPS from Continuing Operations                    5.77
#     Diluted EPS from Discontinued Operations                   NaN
# Basic Weighted Average Shares Outstanding               42,361,000
# Diluted Weighted Average Shares Outstanding             43,439,000
# Reported Normalized Diluted EPS                               9.64
# Basic EPS                                                     5.92
# Diluted EPS                                                   5.77
# Basic WASO                                              42,361,000
# Diluted WASO                                            43,439,000
# Fiscal year ends in Dec 31 | USD                               NaN
